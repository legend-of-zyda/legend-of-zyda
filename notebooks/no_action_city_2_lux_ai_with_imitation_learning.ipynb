# %%
# This notebook is based on the notebook 'Lux AI with imitation learning' by Sazuma (https://www.kaggle.com/shoheiazuma/lux-ai-with-imitation-learning)
# and has been modified to support learning and executing city actions
# This notebook is intended to be used on Google Colab with the replay data stored in Google drive
# !pip install kaggle-environments -U > /dev/null 2>&1

# %%
# Mount the dataset from Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import json
from pathlib import Path
import os
import random
from tqdm.notebook import tqdm
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split

# %%
def seed_everything(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)
    
    if torch.cuda.is_available():
        print("GPU available")
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = True

seed = 42
seed_everything(seed)
# Out:
# GPU available

# %% [markdown]
# # Preprocessing

# %%
# City Tile Actions
def to_label_ct(action):
    strs = action.split(' ')
    #print(strs)
    pos_x = ''
    pos_y = ''
    
    if strs[0] == 'r':
        pos_x = strs[1]
        pos_y = strs[2]
        label = 0
    elif strs[0] == 'bw':
        pos_x = strs[1]
        pos_y = strs[2]
        label = 1
    elif strs[0] == 'bc':
        pos_x = strs[1]
        pos_y = strs[2]
        label = 2
    else:
        # Learn no action for each city tile
        pos_x = '-1'
        pos_y = '-1'
        label = 3
    return pos_x, pos_y, label

def to_label(action):
    strs = action.split(' ')
    unit_id = strs[1]
    if strs[0] == 'm':
        label = {'c': None, 'n': 0, 's': 1, 'w': 2, 'e': 3}[strs[2]]
    elif strs[0] == 'bcity':
        label = 4
    elif strs[0] == 'p':
        label = 5
    elif strs[0] == 't':
        # The transfer actions has a destination, resource type, and amount
        # TODO: handle this 
        label = None
    else:
        label = None
    return unit_id, label


def depleted_resources(obs):
    for u in obs['updates']:
        if u.split(' ')[0] == 'r':
            return False
    return True


def create_dataset_from_json(episode_dir, team_name=None): 
    obses = {}
    obses_ct = {}
    samples = []
    samples_ct = []
    #append = samples.append
    
    episodes = [path for path in Path(episode_dir).glob('*.json') if 'output' not in path.name and 'info' not in path.name]
    for filepath in tqdm(episodes):
        print(filepath)
        with open(filepath) as f:
            json_load = json.load(f)

        ep_id = json_load['info']['EpisodeId']
        index = np.argmax([r or 0 for r in json_load['rewards']])
        if team_name != None and json_load['info']['TeamNames'][index] != team_name:
            continue

        for i in range(len(json_load['steps'])-1):
            if json_load['steps'][i][index]['status'] == 'ACTIVE':
                actions = json_load['steps'][i+1][index]['action']
                obs = json_load['steps'][i][0]['observation']
                
                if depleted_resources(obs):
                    break
                
                obs['player'] = index
                obs = dict([
                    (k,v) for k,v in obs.items() 
                    if k in ['step', 'updates', 'player', 'width', 'height']
                ])
                obs_id = f'{ep_id}_{i}'
                obses[obs_id] = obs
                obses_ct[obs_id] = obs
                                
                for action in actions:
                    unit_id, label = to_label(action)
                    pos_x, pos_y, label_ct = to_label_ct(action)
                    if label is not None:
                        samples.append((obs_id, unit_id, label))
                        #obses[obs_id] = obs
                    if label_ct is not None:
                        samples_ct.append((obs_id, pos_x, pos_y, label_ct))
                        #obses_ct[obs_id] = obs

    return obses, samples, obses_ct, samples_ct

# %%
episode_dir = './drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021'
obses, samples, obses_ct, samples_ct = create_dataset_from_json(episode_dir)
print('obses:', len(obses), 'samples:', len(samples), 'obses_ct:', len(obses_ct), 'samples_ct:', len(samples_ct))
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26688997.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689645.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689435.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689787.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689505.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689365.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689575.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689999.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689929.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689717.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26689859.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690350.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690069.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690632.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690209.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690562.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690139.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690421.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690491.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690280.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691266.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690703.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690774.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690844.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691336.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690914.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691125.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691055.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691195.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26690985.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691763.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691622.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691834.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691692.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691974.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691550.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691904.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691406.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26691479.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692395.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692324.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692254.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692114.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26693490.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692044.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692535.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692184.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26692465.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26695519.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26694432.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26702640.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26703155.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26706806.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26698403.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26699891.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26696866.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26703495.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26723382.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26729534.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26726567.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26712393.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26715363.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26720475.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26718168.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26719466.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26709683.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26732638.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26758547.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26755965.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26739485.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26736172.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26742638.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26752706.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26749368.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26762301.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26745856.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26745905.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26780804.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26777442.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26784088.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26767236.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26787820.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26771265.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26773935.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26765791.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26807117.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26803607.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26814217.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26800071.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26788146.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26810638.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26791851.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26795899.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26818491.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26832151.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26826225.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26839388.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26829777.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26843386.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26814974.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26835897.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26822359.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26874418.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26863030.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26866919.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26863049.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26851477.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26859296.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26870434.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26847510.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26874439.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26855628.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26893313.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26897187.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26900929.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26889821.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26878534.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26897183.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26886148.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26882333.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26917775.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26932952.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26929132.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26913531.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26925280.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26929095.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26921548.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26909477.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26905405.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26946506.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26937006.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26954782.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26958682.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26962798.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26942129.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26966802.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26971210.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26950641.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26996917.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27001434.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26989086.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26975795.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26980169.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26984712.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/26992995.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27038707.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27029061.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27015604.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27010714.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27024529.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27006288.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27033602.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27043554.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27020058.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27066289.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27080630.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27062110.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27075871.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27055078.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27050268.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27048661.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27070926.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27059418.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27119959.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27115023.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27095556.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27109853.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27085438.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27105037.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27125195.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27090693.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27100385.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27158512.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27130163.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27134708.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27139151.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27143794.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27153587.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27148461.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27139149.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27192726.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27173233.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27168439.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27187659.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27177876.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27163292.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27192720.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27197969.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27182935.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27213737.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27223993.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27213131.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27203120.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27203121.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27233762.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27219021.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27208190.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27228746.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27244824.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27239294.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27271403.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27266387.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27276491.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27281910.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27255749.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27261008.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27255748.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27250440.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27293118.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27304041.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27309366.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27318999.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27298526.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27314480.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27324371.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27329549.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27287248.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27347011.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27336135.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27364153.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27358686.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27341354.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27352788.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27352793.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27363854.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27357022.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27335320.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27374808.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375477.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375347.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375218.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375089.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375253.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27369114.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27374559.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27364160.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375734.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376376.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376121.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376769.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375991.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376506.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375605.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376641.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376247.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27375863.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377934.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377674.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27376897.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377155.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377026.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377414.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377546.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377806.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27377285.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378840.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379100.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378970.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378194.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378584.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378064.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378455.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378712.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27378323.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379358.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380127.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379871.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379486.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380258.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379615.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379999.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380387.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379229.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27379743.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27383281.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27381627.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380911.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27387162.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27386088.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380783.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380928.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380655.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27380524.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27388340.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27395354.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27397542.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27403310.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27392090.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27403519.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27391996.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27399217.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27391671.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27407418.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27411809.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27417826.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27406107.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27418648.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27414665.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27408675.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27413397.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27418821.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27430953.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27430099.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27427698.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27427594.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27423970.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27424471.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27426858.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27420800.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27420799.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27445207.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27438984.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27446029.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27446028.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27439817.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27452059.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27433814.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27433021.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27436120.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27452060.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27463359.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27469301.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27463313.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27463357.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27452062.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27468495.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27457800.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27457797.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27469302.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27478886.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27481491.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27475482.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27475476.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27487682.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27475477.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27469306.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27481486.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27496047.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27489857.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27501114.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27495112.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27507329.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27507328.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27505548.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27495113.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27489020.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27489861.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27520788.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27517284.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27519881.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27511729.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27513621.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27517285.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27511730.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27512397.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27511009.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27529436.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27523525.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27528059.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27535585.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27535586.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27535581.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27541929.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27523031.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27532632.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27553414.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27541932.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27548553.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27547742.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27541930.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27547746.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27544321.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27541931.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27547740.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27559011.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27571179.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27571129.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27564901.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27559053.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27553421.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27553457.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27564985.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27583629.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27589656.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27583591.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27577282.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27583631.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27583628.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27589658.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27577327.json
# drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/27589657.json
# obses: 120749 samples: 602495 obses_ct: 120749 samples_ct: 740344

# %%
labels = [sample[-1] for sample in samples]
actions = ['north', 'south', 'west', 'east', 'bcity', 'p']
for value, count in zip(*np.unique(labels, return_counts=True)):
    print(f'{actions[value]:^5}: {count:>3}')

print()
labels_ct = [sample_ct[-1] for sample_ct in samples_ct]
actions_ct = ['research', 'build worker', 'build cart', 'no action']
for value, count in zip(*np.unique(labels_ct, return_counts=True)):
    print(f'{actions_ct[value]:^5}: {count:>3}')
# Out:
# north: 138207
# south: 131639
# west : 142865
# east : 148972
# bcity: 40812
#
# research: 67645
# build worker: 28701
# no action: 643998

# %% [markdown]
# # Training Unit Actions

# %%
# Input for Neural Network
def make_input(obs, unit_id):
    width, height = obs['width'], obs['height']
    x_shift = (32 - width) // 2
    y_shift = (32 - height) // 2
    cities = {}
    
    b = np.zeros((20, 32, 32), dtype=np.float32)
    
    for update in obs['updates']:
        strs = update.split(' ')
        input_identifier = strs[0]
        
        if input_identifier == 'u':
            x = int(strs[4]) + x_shift
            y = int(strs[5]) + y_shift
            wood = int(strs[7])
            coal = int(strs[8])
            uranium = int(strs[9])
            if unit_id == strs[3]:
                # Position and Cargo
                b[:2, x, y] = (
                    1,
                    (wood + coal + uranium) / 100
                )
            else:
                # Units
                team = int(strs[2])
                cooldown = float(strs[6])
                idx = 2 + (team - obs['player']) % 2 * 3
                b[idx:idx + 3, x, y] = (
                    1,
                    cooldown / 6,
                    (wood + coal + uranium) / 100
                )
        elif input_identifier == 'ct':
            # CityTiles
            team = int(strs[1])
            city_id = strs[2]
            x = int(strs[3]) + x_shift
            y = int(strs[4]) + y_shift
            idx = 8 + (team - obs['player']) % 2 * 2
            b[idx:idx + 2, x, y] = (
                1,
                cities[city_id]
            )
        elif input_identifier == 'r':
            # Resources
            r_type = strs[1]
            x = int(strs[2]) + x_shift
            y = int(strs[3]) + y_shift
            amt = int(float(strs[4]))
            b[{'wood': 12, 'coal': 13, 'uranium': 14}[r_type], x, y] = amt / 800
        elif input_identifier == 'rp':
            # Research Points
            team = int(strs[1])
            rp = int(strs[2])
            b[15 + (team - obs['player']) % 2, :] = min(rp, 200) / 200
        elif input_identifier == 'c':
            # Cities
            city_id = strs[2]
            fuel = float(strs[3])
            lightupkeep = float(strs[4])
            cities[city_id] = min(fuel / lightupkeep, 10) / 10
    
    # Day/Night Cycle
    b[17, :] = obs['step'] % 40 / 40
    # Turns
    b[18, :] = obs['step'] / 360
    # Map Size
    b[19, x_shift:32 - x_shift, y_shift:32 - y_shift] = 1

    return b

# %%
class LuxDataset(Dataset):
    def __init__(self, obses, samples):
        self.obses = obses
        self.samples = samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        obs_id, unit_id, action = self.samples[idx]
        obs = self.obses[obs_id]
        state = make_input(obs, unit_id)

        return state, action

# %%
# Neural Network for Lux AI
class BasicConv2d(nn.Module):
    def __init__(self, input_dim, output_dim, kernel_size, bn):
        super().__init__()
        self.conv = nn.Conv2d(
            input_dim, output_dim, 
            kernel_size=kernel_size, 
            padding=(kernel_size[0] // 2, kernel_size[1] // 2)
        )
        self.bn = nn.BatchNorm2d(output_dim) if bn else None

    def forward(self, x):
        h = self.conv(x)
        h = self.bn(h) if self.bn is not None else h
        return h

# %%
class LuxNet(nn.Module):
    def __init__(self):
        super().__init__()
        layers, filters = 12, 32
        self.conv0 = BasicConv2d(20, filters, (3, 3), True)
        self.blocks = nn.ModuleList(
            [BasicConv2d(filters, filters, (3, 3), True) for _ in range(layers)])
        self.head_p = nn.Linear(filters, 5, bias=False)

    def forward(self, x):
        h = F.relu_(self.conv0(x))
        for block in self.blocks:
            h = F.relu_(h + block(h))
        h_head = (h * x[:, :1]).view(h.size(0), h.size(1), -1).sum(-1)
        p = self.head_p(h_head)
        return p

# %%
def train_model(model, dataloaders_dict, criterion, optimizer, num_epochs):
    best_acc = 0.0
    device = torch.device("cpu")
    for epoch in range(num_epochs):
        model.cuda()
        #model.to(device)
        
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
                
            epoch_loss = 0.0
            epoch_acc = 0
            
            dataloader = dataloaders_dict[phase]
            for item in tqdm(dataloader, leave=False):
                states = item[0].cuda().float()
                actions = item[1].cuda().long()

                optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase == 'train'):
                    policy = model(states)
                    loss = criterion(policy, actions)
                    _, preds = torch.max(policy, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                    epoch_loss += loss.item() * len(policy)
                    epoch_acc += torch.sum(preds == actions.data)

            data_size = len(dataloader.dataset)
            epoch_loss = epoch_loss / data_size
            epoch_acc = epoch_acc.double() / data_size

            print(f'Epoch {epoch + 1}/{num_epochs} | {phase:^5} | Loss: {epoch_loss:.4f} | Acc: {epoch_acc:.4f}')
        
        if epoch_acc > best_acc:
            traced = torch.jit.trace(model.cpu(), torch.rand(1, 20, 32, 32))
            traced.save('model.pth')
            best_acc = epoch_acc

# %%
model = LuxNet()
train, val = train_test_split(samples, test_size=0.1, random_state=42, stratify=labels)
batch_size = 64
train_loader = DataLoader(
    LuxDataset(obses, train), 
    batch_size=batch_size, 
    shuffle=True, 
    num_workers=2
)
val_loader = DataLoader(
    LuxDataset(obses, val), 
    batch_size=batch_size, 
    shuffle=False, 
    num_workers=2
)
dataloaders_dict = {"train": train_loader, "val": val_loader}
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

# %%
train_model(model, dataloaders_dict, criterion, optimizer, num_epochs=2)
# Out:
#   0%|          | 0/8473 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7eb64a8c560f> in <module>()
# ----> 1 train_model(model, dataloaders_dict, criterion, optimizer, num_epochs=2)
#
# <ipython-input-12-b1c1f768fb5c> in train_model(model, dataloaders_dict, criterion, optimizer, num_epochs)
#      23
#      24                 with torch.set_grad_enabled(phase == 'train'):
# ---> 25                     policy = model(states)
#      26                     loss = criterion(policy, actions)
#      27                     _, preds = torch.max(policy, 1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1094         return result
#    1095
# -> 1096     def _call_impl(self, *input, **kwargs):
#    1097         forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1098         # If we don't have any hooks, we want to skip the rest of the logic in
#
# KeyboardInterrupt:

# %%
with open('./drive/Shareddrives/CSCI 527 Fall 2021/training_data/replay_10_4_2021/model.pth', 'w') as f:
  f.write('model.pth')

# %% [markdown]
# # Training City actions

# %%
# Input for Neural Network
def make_input_ct(obs, pos_x, pos_y):
    width, height = obs['width'], obs['height']
    x_shift = (32 - width) // 2
    y_shift = (32 - height) // 2
    cities = {}
    
    b = np.zeros((22, 32, 32), dtype=np.float32)
    
    for update in obs['updates']:
        strs = update.split(' ')
        input_identifier = strs[0]
        
        if input_identifier == 'u':
            x = int(strs[4]) + x_shift
            y = int(strs[5]) + y_shift
            wood = int(strs[7])
            coal = int(strs[8])
            uranium = int(strs[9])
            # Units
            team = int(strs[2])
            cooldown = float(strs[6])
            idx = 0 + (team - obs['player']) % 2 * 3
            b[idx:idx + 3, x, y] = (
                1,
                cooldown / 6,
                (wood + coal + uranium) / 100
            )
        # Why is cooldown divided by 6??
        elif input_identifier == 'ct':
            # CityTiles
            team = int(strs[1])
            city_id = strs[2]
            x = int(strs[3]) + x_shift
            y = int(strs[4]) + y_shift
            cooldown = float(strs[5])
            if pos_x == x and pos_y == y:
                b[6:8, x, y] = (
                    1,
                    cities[city_id]
                )
            else:
                idx = 8 + (team - obs['player']) % 2 * 3
                b[idx:idx + 3, x, y] = (
                    1,
                    cities[city_id],
                    cooldown / 6
                )
        elif input_identifier == 'r':
            # Resources
            r_type = strs[1]
            x = int(strs[2]) + x_shift
            y = int(strs[3]) + y_shift
            amt = int(float(strs[4]))
            b[{'wood': 14, 'coal': 15, 'uranium': 16}[r_type], x, y] = amt / 800
        elif input_identifier == 'rp':
            # Research Points
            team = int(strs[1])
            rp = int(strs[2])
            b[17 + (team - obs['player']) % 2, :] = min(rp, 200) / 200
        elif input_identifier == 'c':
            # Cities
            city_id = strs[2]
            fuel = float(strs[3])
            lightupkeep = float(strs[4])
            cities[city_id] = min(fuel / lightupkeep, 10) / 10
    
    # Day/Night Cycle
    b[19, :] = obs['step'] % 40 / 40
    # Turns
    b[20, :] = obs['step'] / 360
    # Map Size
    b[21, x_shift:32 - x_shift, y_shift:32 - y_shift] = 1

    return b

# %%
class LuxDataset(Dataset):
    def __init__(self, obses, samples):
        self.obses = obses
        self.samples = samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        obs_id, pos_x, pos_y, action = self.samples[idx]
        obs = self.obses[obs_id]
        state = make_input_ct(obs, pos_x=pos_x, pos_y=pos_y)

        return state, action

# %%
# Neural Network for Lux AI
class BasicConv2d(nn.Module):
    def __init__(self, input_dim, output_dim, kernel_size, bn):
        super().__init__()
        self.conv = nn.Conv2d(
            input_dim, output_dim, 
            kernel_size=kernel_size, 
            padding=(kernel_size[0] // 2, kernel_size[1] // 2)
        )
        self.bn = nn.BatchNorm2d(output_dim) if bn else None

    def forward(self, x):
        h = self.conv(x)
        h = self.bn(h) if self.bn is not None else h
        return h

# %%
class LuxNet(nn.Module):
    def __init__(self):
        super().__init__()
        layers, filters = 12, 32
        self.conv0 = BasicConv2d(22, filters, (3, 3), True)
        self.blocks = nn.ModuleList(
            [BasicConv2d(filters, filters, (3, 3), True) for _ in range(layers)])
        self.head_p = nn.Linear(filters, 4, bias=False)

    def forward(self, x):
        h = F.relu_(self.conv0(x))
        for block in self.blocks:
            h = F.relu_(h + block(h))
        h_head = (h * x[:, :1]).view(h.size(0), h.size(1), -1).sum(-1)
        p = self.head_p(h_head)
        return p

# %%
def train_model(model, dataloaders_dict, criterion, optimizer, num_epochs):
    best_acc = 0.0
    device = torch.device("cpu")
    for epoch in range(num_epochs):
        model.cuda()
        #model.to(device)
        
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
                
            epoch_loss = 0.0
            epoch_acc = 0
            
            dataloader = dataloaders_dict[phase]
            for item in tqdm(dataloader, leave=False):
                states = item[0].cuda().float()
                actions = item[1].cuda().long()

                optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase == 'train'):
                    policy = model(states)
                    loss = criterion(policy, actions)
                    _, preds = torch.max(policy, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                    epoch_loss += loss.item() * len(policy)
                    epoch_acc += torch.sum(preds == actions.data)

            data_size = len(dataloader.dataset)
            epoch_loss = epoch_loss / data_size
            epoch_acc = epoch_acc.double() / data_size

            print(f'Epoch {epoch + 1}/{num_epochs} | {phase:^5} | Loss: {epoch_loss:.4f} | Acc: {epoch_acc:.4f}')
        
        if epoch_acc > best_acc:
            traced = torch.jit.trace(model.cpu(), torch.rand(1, 22, 32, 32))
            traced.save('model_ct.pth')
            best_acc = epoch_acc

# %%
model = LuxNet()
train, val = train_test_split(samples_ct, test_size=0.1, random_state=42, stratify=labels_ct)
batch_size = 64
train_loader = DataLoader(
    LuxDataset(obses_ct, train), 
    batch_size=batch_size, 
    shuffle=True, 
    num_workers=2
)
val_loader = DataLoader(
    LuxDataset(obses_ct, val), 
    batch_size=batch_size, 
    shuffle=False, 
    num_workers=2
)
dataloaders_dict = {"train": train_loader, "val": val_loader}
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

# %%
train_model(model, dataloaders_dict, criterion, optimizer, num_epochs=10)
# Out:
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 1/10 | train | Loss: 0.4436 | Acc: 0.8673
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 1/10 |  val  | Loss: 0.3992 | Acc: 0.8701
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 2/10 | train | Loss: 0.3809 | Acc: 0.8709
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 2/10 |  val  | Loss: 0.3726 | Acc: 0.8714
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 3/10 | train | Loss: 0.3673 | Acc: 0.8718
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 3/10 |  val  | Loss: 0.3695 | Acc: 0.8721
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 4/10 | train | Loss: 0.3607 | Acc: 0.8729
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 4/10 |  val  | Loss: 0.3604 | Acc: 0.8740
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 5/10 | train | Loss: 0.3562 | Acc: 0.8736
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 5/10 |  val  | Loss: 0.3668 | Acc: 0.8743
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 6/10 | train | Loss: 0.3525 | Acc: 0.8742
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 6/10 |  val  | Loss: 0.3559 | Acc: 0.8747
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 7/10 | train | Loss: 0.3498 | Acc: 0.8746
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 7/10 |  val  | Loss: 0.3576 | Acc: 0.8743
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 8/10 | train | Loss: 0.3479 | Acc: 0.8750
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 8/10 |  val  | Loss: 0.3574 | Acc: 0.8742
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 9/10 | train | Loss: 0.3459 | Acc: 0.8755
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 9/10 |  val  | Loss: 0.3620 | Acc: 0.8738
#   0%|          | 0/10412 [00:00<?, ?it/s]
# Epoch 10/10 | train | Loss: 0.3443 | Acc: 0.8756
#   0%|          | 0/1157 [00:00<?, ?it/s]
# Epoch 10/10 |  val  | Loss: 0.3610 | Acc: 0.8744

# %%
with open('./drive/Shareddrives/CSCI 527 Fall 2021/training_data/model_ct_no_action.pth', 'w') as f:
  f.write('model_ct.pth')

# %% [markdown]
# # Submission

# %%
# %%writefile agent.py
import os
import numpy as np
import torch
from lux.game import Game


path = '/kaggle_simulations/agent' if os.path.exists('/kaggle_simulations') else '.'
model = torch.jit.load(f'{path}/model.pth')
model.eval()

model_ct = torch.jit.load(f'{path}/model_ct.pth')
model_ct.eval()

# Input for Neural Network
def make_input_ct(obs, pos_x, pos_y):
    width, height = obs['width'], obs['height']
    x_shift = (32 - width) // 2
    y_shift = (32 - height) // 2
    cities = {}
    
    b = np.zeros((22, 32, 32), dtype=np.float32)
    
    for update in obs['updates']:
        strs = update.split(' ')
        input_identifier = strs[0]
        
        if input_identifier == 'u':
            x = int(strs[4]) + x_shift
            y = int(strs[5]) + y_shift
            wood = int(strs[7])
            coal = int(strs[8])
            uranium = int(strs[9])
            """
            if unit_id == strs[3]:
                # Position and Cargo
                b[:2, x, y] = (
                    1,
                    (wood + coal + uranium) / 100
                )
            else:
            """
            # Units
            team = int(strs[2])
            cooldown = float(strs[6])
            idx = 0 + (team - obs['player']) % 2 * 3
            b[idx:idx + 3, x, y] = (
                1,
                cooldown / 6,
                (wood + coal + uranium) / 100
            )
        # Why is cooldown divided by 6??
        elif input_identifier == 'ct':
            # CityTiles
            team = int(strs[1])
            city_id = strs[2]
            x = int(strs[3]) + x_shift
            y = int(strs[4]) + y_shift
            cooldown = float(strs[5])
            if pos_x == x and pos_y == y:
                b[6:8, x, y] = (
                    1,
                    cities[city_id]
                )
            else:
                idx = 8 + (team - obs['player']) % 2 * 3
                b[idx:idx + 3, x, y] = (
                    1,
                    cities[city_id],
                    cooldown / 6
                )
        elif input_identifier == 'r':
            # Resources
            r_type = strs[1]
            x = int(strs[2]) + x_shift
            y = int(strs[3]) + y_shift
            amt = int(float(strs[4]))
            b[{'wood': 14, 'coal': 15, 'uranium': 16}[r_type], x, y] = amt / 800
        elif input_identifier == 'rp':
            # Research Points
            team = int(strs[1])
            rp = int(strs[2])
            b[17 + (team - obs['player']) % 2, :] = min(rp, 200) / 200
        elif input_identifier == 'c':
            # Cities
            city_id = strs[2]
            fuel = float(strs[3])
            lightupkeep = float(strs[4])
            cities[city_id] = min(fuel / lightupkeep, 10) / 10
    
    # Day/Night Cycle
    b[19, :] = obs['step'] % 40 / 40
    # Turns
    b[20, :] = obs['step'] / 360
    # Map Size
    b[21, x_shift:32 - x_shift, y_shift:32 - y_shift] = 1

return b


def make_input(obs, unit_id):
    width, height = obs['width'], obs['height']
    x_shift = (32 - width) // 2
    y_shift = (32 - height) // 2
    cities = {}
    
    b = np.zeros((20, 32, 32), dtype=np.float32)
    
    for update in obs['updates']:
        strs = update.split(' ')
        input_identifier = strs[0]
        
        if input_identifier == 'u':
            x = int(strs[4]) + x_shift
            y = int(strs[5]) + y_shift
            wood = int(strs[7])
            coal = int(strs[8])
            uranium = int(strs[9])
            if unit_id == strs[3]:
                # Position and Cargo
                b[:2, x, y] = (
                    1,
                    (wood + coal + uranium) / 100
                )
            else:
                # Units
                team = int(strs[2])
                cooldown = float(strs[6])
                idx = 2 + (team - obs['player']) % 2 * 3
                b[idx:idx + 3, x, y] = (
                    1,
                    cooldown / 6,
                    (wood + coal + uranium) / 100
                )
        elif input_identifier == 'ct':
            # CityTiles
            team = int(strs[1])
            city_id = strs[2]
            x = int(strs[3]) + x_shift
            y = int(strs[4]) + y_shift
            idx = 8 + (team - obs['player']) % 2 * 2
            b[idx:idx + 2, x, y] = (
                1,
                cities[city_id]
            )
        elif input_identifier == 'r':
            # Resources
            r_type = strs[1]
            x = int(strs[2]) + x_shift
            y = int(strs[3]) + y_shift
            amt = int(float(strs[4]))
            b[{'wood': 12, 'coal': 13, 'uranium': 14}[r_type], x, y] = amt / 800
        elif input_identifier == 'rp':
            # Research Points
            team = int(strs[1])
            rp = int(strs[2])
            b[15 + (team - obs['player']) % 2, :] = min(rp, 200) / 200
        elif input_identifier == 'c':
            # Cities
            city_id = strs[2]
            fuel = float(strs[3])
            lightupkeep = float(strs[4])
            cities[city_id] = min(fuel / lightupkeep, 10) / 10
    
    # Day/Night Cycle
    b[17, :] = obs['step'] % 40 / 40
    # Turns
    b[18, :] = obs['step'] / 360
    # Map Size
    b[19, x_shift:32 - x_shift, y_shift:32 - y_shift] = 1

    return b


game_state = None
def get_game_state(observation):
    global game_state
    
    if observation["step"] == 0:
        game_state = Game()
        game_state._initialize(observation["updates"])
        game_state._update(observation["updates"][2:])
        game_state.id = observation["player"]
    else:
        game_state._update(observation["updates"])
    return game_state


def in_city(pos):    
    try:
        city = game_state.map.get_cell_by_pos(pos).citytile
        return city is not None and city.team == game_state.id
    except:
        return False


def call_func(obj, method, args=[]):
    return getattr(obj, method)(*args)


unit_actions = [('move', 'n'), ('move', 's'), ('move', 'w'), ('move', 'e'), ('build_city',), ('pillage',)]
def get_action(policy, unit, dest):
    for label in np.argsort(policy)[::-1]:
        act = unit_actions[label]
        pos = unit.pos.translate(act[-1], 1) or unit.pos
        if pos not in dest or in_city(pos):
            return call_func(unit, *act), pos 
            
    return unit.move('c'), unit.pos


def agent(observation, configuration):
    global game_state
    
    game_state = get_game_state(observation)    
    player = game_state.players[observation.player]
    actions = []
    
    # City Actions
    """
    unit_count = len(player.units)
    for city in player.cities.values():
        for city_tile in city.citytiles:
            if city_tile.can_act():
                if unit_count < player.city_tile_count: 
                    actions.append(city_tile.build_worker())
                    unit_count += 1
                elif not player.researched_uranium():
                    actions.append(city_tile.research())
                    player.research_points += 1
    """

    #unit_count = len(player.units)
    for city in player.cities.values():
        for city_tile in city.citytiles:
            if city_tile.can_act():
                state = make_input_ct(observation, city_tile.pos.x, city_tile.pos.y)
                    with torch.no_grad():
                        p = model_ct(torch.from_numpy(state).unsqueeze(0))

                    policy = p.squeeze(0).numpy()
                    #for label in np.argsort(policy)[::-1]:
                        #act = unit_actions[label]
                    label = np.argmax(policy)
                    if label == 0:
                        actions.append(city_tile.research())
                    elif label == 1:
                        actions.append(city_tile.build_worker())
                    elif label == 2:
                        actions.append(city_tile.build_cart())
                    else:
                        print(p)
                        print(policy)
                        print(label)
                        print("ERROR: Invalid city action")


    
    # Worker Actions
    dest = []
    for unit in player.units:
        if unit.can_act() and (game_state.turn % 40 < 30 or not in_city(unit.pos)):
            state = make_input(observation, unit.id)
            with torch.no_grad():
                p = model(torch.from_numpy(state).unsqueeze(0))

            policy = p.squeeze(0).numpy()

            action, pos = get_action(policy, unit, dest)
            actions.append(action)
            dest.append(pos)

    return actions

# %%
from kaggle_environments import make

env = make("lux_ai_2021", configuration={"width": 24, "height": 24, "loglevel": 2, "annotations": True}, debug=False)
steps = env.run(['agent.py', 'agent.py'])
env.render(mode="ipython", width=1200, height=800)
